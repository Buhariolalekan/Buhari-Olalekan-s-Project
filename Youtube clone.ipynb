# %%
<!DOCTYPE html>
<html>
  <title>Youtube.com Clone</title>

  <link rel="preconnect" href="https://fonts.googleapis.com" />
  <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin />
  <link
    href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&display=swap"
    rel="stylesheet"
  />

  <head>
    <link rel="stylesheet" href="styles/general.css" />
    <link rel="stylesheet" href="styles/header.css" />
    <link rel="stylesheet" href="styles/video.css" />
  </head>
  <body>
    <div class="header">
      <div class="left-section">left section</div>
      <div class="center-section">
        <input class="search-bar" type="text" placeholder="Search" />
      </div>
      <div class="right-section">right section</div>
    </div>

    <div class="video-grid">
      <div class="video-preview">
        <div class="image-div">
          <img class="images" src="images/thumbnail-1.webp" />
        </div>
        <div class="video-info-grid">
          <div class="channel-div">
            <img class="channel-picture" src="channel-picture/channel-1.jpeg" />
          </div>
          <div class="div-text">
            <p class="text-bar">
              Talking Tech and Al with Google CEO Sundar Pichai!
            </p>
            <p class="author">Marques Brownlee</p>
            <p class="view">3.4M views &#183; 6 months ago</p>
          </div>
        </div>
      </div>

      <div class="video-preview">
        <div class="imgg-div">
          <img class="images" src="images/youtube clone.webp" />
        </div>
        <div class="video-info-grid">
          <div class="img-div">
            <img class="img" src="channel-picture/channel-2.jpeg" />
          </div>
          <div class="text-div">
            <p class="text-bar">Try Not To Laugh Challenge #9</p>
            <p class="author">Markiplier</p>
            <p class="view">9M views &#183; 4 years ago</p>
          </div>
        </div>
      </div>

      <div class="video-preview">
        <div class="image-div">
          <img class="images" src="images/thumbnail-3.webp" />
        </div>
        <div class="video-info-grid">
          <div class="channel-div">
            <img class="channel-picture" src="channel-picture/channel-3.jpeg" />
          </div>
          <div class="div-text">
            <p class="text-bar">Crazy Tik Toks Taken Moments Before DISASTER</p>
            <p class="author">SSSniperWolf</p>
            <p class="view">12M views &#183; 1 year ago</p>
          </div>
        </div>
      </div>

      <div class="video-preview">
        <div class="imgg-div">
          <img class="images" src="images/thumbnail-4.webp" />
        </div>
        <div class="video-info-grid">
          <div class="img-div">
            <img class="img" src="channel-picture/channel-4.jpeg" />
          </div>
          <div class="text-div">
            <p class="text-bar">
              The Simplest Math Problem No one Can Solve - Collatz Conjecture
            </p>
            <p class="author">Veritasium</p>
            <p class="view">18M views &#183; 4 months ago</p>
          </div>
        </div>
      </div>

      <div class="video-preview">
        <div class="image-div">
          <img class="images" src="images/thumbnail-5.webp" />
        </div>
        <div class="video-info-grid">
          <div class="channel-div">
            <img class="channel-picture" src="channel-picture/channel-5.jpeg" />
          </div>
          <div class="div-text">
            <p class="text-bar">
              Kadane's Algorithm to Maximum Sum Subarray Problem
            </p>
            <p class="author">CS Dojo</p>
            <p class="view">519K views &#183; 5 years ago</p>
          </div>
        </div>
      </div>

      <div class="video-preview">
        <div class="imgg-div">
          <img class="images" src="images/thumbnail-6.webp" />
        </div>
        <div class="video-info-grid">
          <div class="img-div">
            <img class="img" src="channel-picture/channel-6.jpeg" />
          </div>
          <div class="text-div">
            <p class="text-bar">
              Anything You Can Fit In The Circle I'll Pay For
            </p>
            <p class="author">MrBeast</p>
            <p class="view">141M views &#183; 1 year ago</p>
          </div>
        </div>
      </div>
    </div>
  </body>
</html>
